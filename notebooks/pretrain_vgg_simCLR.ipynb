# %%
import os

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
print(tf.__version__)
# Out:
# 2.5.0

# %%
from SimCLR_Keras.Scripts.pretain_vgg16 import pretain_vgg16

pretain_vgg16(
    save_path='/content/drive/MyDrive/Doctorado/proyectos/Van Gogh/model_training/models/SimCLR',
    data_dir='/content/drive/MyDrive/Doctorado/proyectos/Van Gogh/model_training/train_data',
    random_state=42,
    epochs=4000,
    patience=20,
    batch_size=32,
    input_shape=(80, 80, 3)
)
# Out:
# ...
# 58892288/58889256 [==============================] - 1s 0us/step
#
# ========= Build VGG16 base model loaded =========
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 80, 80, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 80, 80, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 80, 80, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 40, 40, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 40, 40, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 40, 40, 128)       147584
# ...

# %% [markdown]
# **To prevent colab to disconnect because of timeout interactions run this code in the devtool console**
#
# ```
# function ClickConnect(){
#   console.log("Connnect Clicked - Start");
#   document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click();
#   console.log("Connnect Clicked - End");
# };
# setInterval(ClickConnect, 60000)
# ```
