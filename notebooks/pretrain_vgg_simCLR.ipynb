# %%
import os

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
print(tf.__version__)
# Out:
# Found GPU at: /device:GPU:0
# 2.2.0

# %%
from SimCLR_Keras.Scripts.pretain_vgg16 import pretain_vgg16

pretain_vgg16(
    save_path='./SimCLR',
    data_dir='./train_data',
    random_state=42,
    epochs=4000,
    patience=20,
    batch_size=32,
    input_shape=(80, 80, 3)
)
# Out:
# ========= Build VGG16 base model loaded =========
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 80, 80, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 80, 80, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 80, 80, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 40, 40, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 40, 40, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 40, 40, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 20, 20, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 20, 20, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 20, 20, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 20, 20, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 10, 10, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 10, 10, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 5, 5, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 5, 5, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 5, 5, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 5, 5, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
#
# ========= Build SimCLR model to train =========
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1280         try:
# -> 1281             self._accessor.mkdir(self, mode)
#    1282         except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Doctorado/proyectos/Van Gogh/model_training/models/SimCLR'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1280         try:
# -> 1281             self._accessor.mkdir(self, mode)
#    1282         except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Doctorado/proyectos/Van Gogh/model_training/models'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1280         try:
# -> 1281             self._accessor.mkdir(self, mode)
#    1282         except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Doctorado/proyectos/Van Gogh/model_training'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1280         try:
# -> 1281             self._accessor.mkdir(self, mode)
#    1282         except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Doctorado/proyectos/Van Gogh'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1280         try:
# -> 1281             self._accessor.mkdir(self, mode)
#    1282         except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Doctorado/proyectos'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1280         try:
# -> 1281             self._accessor.mkdir(self, mode)
#    1282         except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Doctorado'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1280         try:
# -> 1281             self._accessor.mkdir(self, mode)
#    1282         except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1280         try:
# -> 1281             self._accessor.mkdir(self, mode)
#    1282         except FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-2-6ed544813a03> in <module>
#       1 from SimCLR_Keras.Scripts.pretain_vgg16 import pretain_vgg16
#       2
# ----> 3 pretain_vgg16(
#       4     save_path='/content/drive/MyDrive/Doctorado/proyectos/Van Gogh/model_training/models/SimCLR',
#       5     data_dir='/content/drive/MyDrive/Doctorado/proyectos/Van Gogh/model_training/train_data',
#
# ~/git/doctorado/SimCLRv1-keras-tensorflow/SimCLR_Keras/Scripts/pretain_vgg16.py in pretain_vgg16(save_path, data_dir, df_sep, input_shape, batch_size, feat_dims_ph, augmentation_functions, num_of_unfrozen_layers, epochs, patience, test_size, track_weight_change, gpu_allow_growth, random_state)
#      62
#      63     print('\n========= Build SimCLR model to train =========')
# ---> 64     model = SimCLR(
#      65         base_model=base_model,
#      66         input_shape=input_shape,
#
# ~/git/doctorado/SimCLRv1-keras-tensorflow/SimCLR_Keras/model.py in __init__(self, base_model, input_shape, batch_size, feat_dims_ph, num_of_unfrozen_layers, ph_activation, ph_regul, lr, loss, save_path, r)
#      64
#      65         # Create save directory
# ---> 66         Path(self.save_path).mkdir(parents=True, exist_ok=True)
#      67
#      68         # Different layers around base_model
#
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1283             if not parents or self.parent == self:
#    1284                 raise
# -> 1285             self.parent.mkdir(parents=True, exist_ok=True)
#    1286             self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1287         except OSError:
#
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1283             if not parents or self.parent == self:
#    1284                 raise
# -> 1285             self.parent.mkdir(parents=True, exist_ok=True)
#    1286             self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1287         except OSError:
#
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1283             if not parents or self.parent == self:
#    1284                 raise
# -> 1285             self.parent.mkdir(parents=True, exist_ok=True)
#    1286             self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1287         except OSError:
#
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1283             if not parents or self.parent == self:
#    1284                 raise
# -> 1285             self.parent.mkdir(parents=True, exist_ok=True)
#    1286             self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1287         except OSError:
#
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1283             if not parents or self.parent == self:
#    1284                 raise
# -> 1285             self.parent.mkdir(parents=True, exist_ok=True)
#    1286             self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1287         except OSError:
#
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1283             if not parents or self.parent == self:
#    1284                 raise
# -> 1285             self.parent.mkdir(parents=True, exist_ok=True)
#    1286             self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1287         except OSError:
#
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1283             if not parents or self.parent == self:
#    1284                 raise
# -> 1285             self.parent.mkdir(parents=True, exist_ok=True)
#    1286             self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1287         except OSError:
#
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1283             if not parents or self.parent == self:
#    1284                 raise
# -> 1285             self.parent.mkdir(parents=True, exist_ok=True)
#    1286             self.mkdir(mode, parents=False, exist_ok=exist_ok)
#    1287         except OSError:
#
# ~/anaconda3/envs/van-gogh/lib/python3.8/pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1279             self._raise_closed()
#    1280         try:
# -> 1281             self._accessor.mkdir(self, mode)
#    1282         except FileNotFoundError:
#    1283             if not parents or self.parent == self:
#
# PermissionError: [Errno 13] Permission denied: '/content'

# %% [markdown]
# **To prevent colab to disconnect because of timeout interactions run this code in the devtool console**
#
# ```
# function ClickConnect(){
#   console.log("Connnect Clicked - Start");
#   document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click();
#   console.log("Connnect Clicked - End");
# };
# setInterval(ClickConnect, 60000)
# ```
